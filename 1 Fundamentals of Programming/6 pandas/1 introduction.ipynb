# %% [markdown]
# # What is pandas-python? Introduction and Installation

# %% [markdown]
# Pandas is python module that makes data science easy and effective

# %% [markdown]
# Weather dataset

# %% [markdown]
# Questions?
#
# 1. What was the maximum temparature in new york in the month of january?
#
# 2. On which days did it rains?
#
# 3. What was the average speed of wind during the month?

# %% [markdown]
# First we will see in python code

# %%
# now we will see in pandas 
import pandas as pd
df = pd.read_csv("https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing")
df
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style>@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic')  \
# 0                                                 try{
# 1                                               var aa
# 2    if("function"==typeof Object.setPrototypeOf)da...
# 3                                       _.p=function(a
# 4                                        ma=function(a
# 5                     ma("String.prototype.startsWith"
# 6    var na=function(){na=function(){};la.Symbol||(...
# 7    var oa=function(){function a(d){if(this instan...
# 8                 a instanceof String&&(a+="");var d=0
# 9                                    var ta=function(a
# 10                                        ma("WeakMap"
# 11   var g="$jscomp_hidden_"+Math.random();f("freez...
# 12                       function(m){return d(m)&&ta(m
# 13                                            ma("Map"
# 14   this.b=g();this.size=0;if(l){l=_.ba(l);for(var...
# 15                                             l.Xa.Yb
# 16                     t;!(t=n.next()).done;)t=t.value
# 17                                              n.next
# 18                                            ma("Set"
# 19   if(d){d=_.ba(d);for(var e;!(e=d.next()).done;)...
# 20   c.prototype[Symbol.iterator]=c.prototype.value...
# 21                                 ma("Object.entries"
# 22   _.Ba=function(a){var c=typeof a;if("object"==c...
# 23   else if("function"==c&&"undefined"==typeof a.c...
# 24                                       Ha=function(a
# 25                                     _.Ia=function(a
# 26                                      _.w=function(a
# 27   _.La=function(a){var c=null;if("undefined"===t...
# 28   _.Ma=function(a){if(Error.captureStackTrace)Er...
# 29              _.Pa=Array.prototype.filter?function(a
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                  ]
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                  ]
# 271                                                NaN
# 272  };</script><div ng-non-bindable=""></div><scri...
# 273                                               try{
# 274                   if(_.qj){var tj;if(tj=_.B(_.qj.f
# 275                     }catch(e){_._DumpException(e)}
# 276                                               try{
# 277                          _.wj=function(a){_.A(this
# 278                     }catch(e){_._DumpException(e)}
# 279                                               try{
# 280                                  var xj=function(a
# 281                                    var Cj=_.G(_.sd
# 282                  (function(){var a=_.td();if(_.C(a
# 283                     }catch(e){_._DumpException(e)}
# 284                                    })(this.gbar_);
# 285                                     // Google Inc.
# 286                            </script></body></html>
#
#                                 local('Roboto-Italic')  \
# 0                                                  NaN
# 1                                                   ca
# 2    ia={};try{ia.__proto__=ha;fa=ia.Og;break a}cat...
# 3    c){a.prototype=ca(c.prototype);a.prototype.con...
# 4    c){if(c){var d=la;a=a.split(".");for(var e=0;e...
# 5                    function(a){return a?a:function(c
# 6                                        pa=function(a
# 7                               d)}var c=0;return a}()
# 8    e={next:function(){if(d<a.length){var f=d++;re...
# 9     c){return Object.prototype.hasOwnProperty.call(a
# 10   function(a){function c(){}function d(m){var n=...
# 11   l=function(m){this.b=(h+=Math.random()+1).toSt...
# 12                                         g)&&ta(m[g]
# 13   function(a){if(function(){if(!a||"function"!=t...
# 14                                       this.set(m[0]
# 15                                      l.Xa.head=null
# 16                                            l.call(m
# 17                                            {done:!1
# 18   function(a){if(function(){if(!a||"function"!=t...
# 19   d);this.size=this.b.size;return this};c.protot...
# 20   e){var f=this;this.b.forEach(function(g){retur...
# 21         function(a){return a?a:function(c){var d=[]
# 22                                                 NaN
# 23                                                   c
# 24                                                   c
# 25       c){var d=Array.prototype.slice.call(arguments
# 26   c){function d(){}d.prototype=c.prototype;a.J=c...
# 27                                      {createHTML:Ka
# 28   _.Ma);else{var c=Error().stack;c&&(this.stack=...
# 29                                                   c
# ..                                                 ...
# 257                                                NaN
# 258                  ["https://youtube.googleapis.com"
# 259                                                  1
# 260                                            [1.0E-4
# 261                                                  1
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                    itemJson: [null
# 268                                                NaN
# 269                                                 []
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                             3))for(var uj=_.mh(tj)
# 275                                                NaN
# 276                                                NaN
# 277                                                  a
# 278                                                NaN
# 279                                                NaN
# 280                                                  c
# 281                                                 Bj
# 282                          18))Gj();else{var c=_.B(a
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:local('Roboto Light')  \
# 0                                                  NaN
# 1                                                   da
# 2    c){a.__proto__=c;if(a.__proto__!==c)throw new ...
# 3    c);else for(var d in c)if("prototype"!=d)if(Ob...
# 4                                                    a
# 5    d){if(null==this)throw new TypeError("b`starts...
# 6                                  c){this.b=a;ka(this
# 7    ra=function(){na();var a=la.Symbol.iterator;a|...
# 8                                                a[f])
# 9                                                 c)};
# 10                                g)){var n=new c;ka(m
# 11                                       this.set(n[0]
# 12         this.b)?delete m[g][this.b]:!1};return l});
# 13                                    m=new a(_.ba([[l
# 14                  m[1])}};d.prototype.set=function(l
# 15                                         this.size--
# 16                                                t[1]
# 17                   value:m(n)};n=null}return{done:!0
# 18   e=new a(_.ba([d]));if(!e.has(d)||1!=e.size||e....
# 19                                                 NaN
# 20                                                   g
# 21                                   e;for(e in c)ta(c
# 22                                                 NaN
# 23                       d){return a.call.apply(a.bind
# 24   d){if(!a)throw Error();if(2<arguments.length){...
# 25   1);return function(){var e=d.slice();e.push.ap...
# 26                                                   f
# 27                                     createScript:Ka
# 28   Error);_.Ma.prototype.name="CustomError";_.Na=...
# 29             d){return Array.prototype.filter.call(a
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                  1
# 260  //www.google.com/insights/consumersurveys/asyn...
# 261                                                NaN
# 262                                                  1
# 263                                                  1
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                    nyc_weather.csv
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                 vj=0;vj<uj.length;vj++)_.Zh(uj[vj]
# 275                                                NaN
# 276                                                NaN
# 277                                                  0
# 278                                                NaN
# 279                                                NaN
# 280                                     d){_.xd.log(46
# 281                                        17)||new Bj
# 282              19)||0;window.addEventListener("load"
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
#
#                                  local('Roboto-Light')  \
# 0                                                  NaN
# 1                                                   ja
# 2                                                  NaN
# 3                        d);e&&Object.defineProperty(a
# 4                                     {configurable:!0
# 5                              f=c.length;d=Math.max(0
# 6                                          description
# 7                                                    a
# 8            done:!1}}e.next=function(){return{done:!0
# 9                                                  NaN
# 10                                                   g
# 11                  n[1])}};l.prototype.set=function(m
# 12                                                 NaN
# 13   s]]));if("s"!=m.get(l)||1!=m.size||m.get({x:4}...
# 14                         m){l=0===l?0:l;var n=e(this
# 15   !0):!1};d.prototype.clear=function(){this.f={}...
# 16                                                t[0]
# 17                                    value:void 0}})}
# 18   g=f.next();if(g.done||g.value[0]!=d||g.value[1...
# 19                                                 NaN
# 20                                                   g
# 21                                       e)&&d.push([e
# 22                                                 NaN
# 23                                        arguments)};
# 24   2);return function(){var f=Array.prototype.sli...
# 25                      arguments);return a.apply(this
# 26              g){for(var h=Array(arguments.length-2)
# 27                                  createScriptURL:Ka
# 28            c){return Array.prototype.indexOf.call(a
# 29                                                   c
# ..                                                 ...
# 257                                                  1
# 258                                                 2]
# 259                                                NaN
# 260                                                NaN
# 261                                                  3
# 262         ["AIzaSyCMp6sr4oTC18AWkE2Ii4UBZHTHEpGZWZM"
# 263                                                NaN
# 264                                                  1
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                               ogpc
# 275                                                NaN
# 276                                                NaN
# 277                                                 -1
# 278                                                NaN
# 279                                                NaN
# 280                                             {att:a
# 281                                                 Dj
# 282                    function(){window.setTimeout(Gj
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular')  \
# 0                                                  NaN
# 1                                                   ka
# 2                                                  NaN
# 3                                                    d
# 4                                          writable:!0
# 5                                         Math.min(d|0
# 6                                     {configurable:!0
# 7                                     {configurable:!0
# 8    value:void 0}};return e.next()}};e[Symbol.iter...
# 9                                                  NaN
# 10   {value:n})}}function f(m){var n=Object[m];n&&(...
# 11          n){if(!d(m))throw Error("e");e(m);if(!ta(m
# 12                                                 NaN
# 13         t)!=m||2!=m.size)return!1;var n=m.entries()
# 14   l);n.list||(n.list=this.f[n.id]=[]);n.Xa?n.Xa....
# 15   l).Xa};d.prototype.get=function(l){return(l=e(...
# 16   this)};d.prototype[Symbol.iterator]=d.prototyp...
# 17   g=function(){var l={};return l.Yb=l.next=l.hea...
# 18                                                 NaN
# 19                                                 NaN
# 20                    f)})};return c});ma("Array.from"
# 21   c[e]]);return d}});_.ua=_.ua||{};_.q=this||sel...
# 22                                                 NaN
# 23                                                 NaN
# 24                                 e);return a.apply(c
# 25   e)}};_.Ja=Date.now||function(){return+new Date...
# 26   l=2;l<arguments.length;l++)h[l-2]=arguments[l]...
# 27   createURL:Ka})}catch(d){_.q.console&&_.q.conso...
# 28                                                   c
# 29                                      d)}:function(a
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262        https://blobcomments-pa.clients6.google.com
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                        );_.kj(_.qj
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                              max:c
# 281                                      Aj=(Dj=_.G(Cj
# 282                                         c)})}})();
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
#
#                                local('Roboto-Regular')  \
# 0                                                  NaN
# 1                                                   la
# 2                                                  NaN
# 3    e)}else a[d]=c[d];a.J=c.prototype};ka="functio...
# 4                                         value:c})}};
# 5    this.length));for(var g=0;g<f&&d<e;)if(this[d+...
# 6                                          writable:!0
# 7                                          writable:!0
# 8     function(a){return a?a:function(){return sa(this
# 9                                                  NaN
# 10                                   n=Object.seal({})
# 11   g))throw Error("f`"+m);m[g][this.b]=n;return t...
# 12                                                 NaN
# 13   t=n.next();if(t.done||t.value[0]!=l||"s"!=t.va...
# 14                                        Yb:this.b.Yb
# 15   l).Xa)&&l.value};d.prototype.entries=function(...
# 16   m){var n=m&&typeof m;"object"==n||"function"==...
# 17                                     h=0;return d});
# 18                                                 NaN
# 19                                                 NaN
# 20                   function(a){return a?a:function(c
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24              f)}}return function(){return a.apply(c
# 25   c){a=a.split(".");var d=_.q;a[0]in d||"undefin...
# 26                      h)}};Ka=function(a){return a};
# 27                                                 NaN
# 28                                 void 0)}:function(a
# 29                                                   c
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                  1
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                  1
# 264                                                NaN
# 265                                                  0
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                              !!_.qj.b&&_.qj.b.Sb()
# 275                                                NaN
# 276                                                NaN
# 277                                    null)};_.w(_.wj
# 278                                                NaN
# 279                                                NaN
# 280                                           url:d})}
# 281                                               _.wj
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# ...
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
#
#     null.35 null.36 [""]]]  \
# 0       NaN     NaN    NaN
# 1       NaN     NaN    NaN
# 2       NaN     NaN    NaN
# 3       NaN     NaN    NaN
# 4       NaN     NaN    NaN
# 5       NaN     NaN    NaN
# 6       NaN     NaN    NaN
# 7       NaN     NaN    NaN
# 8       NaN     NaN    NaN
# 9       NaN     NaN    NaN
# 10      NaN     NaN    NaN
# 11      NaN     NaN    NaN
# 12      NaN     NaN    NaN
# 13      NaN     NaN    NaN
# 14      NaN     NaN    NaN
# 15      NaN     NaN    NaN
# 16      NaN     NaN    NaN
# 17      NaN     NaN    NaN
# 18      NaN     NaN    NaN
# 19      NaN     NaN    NaN
# 20      NaN     NaN    NaN
# 21      NaN     NaN    NaN
# 22      NaN     NaN    NaN
# 23      NaN     NaN    NaN
# 24      NaN     NaN    NaN
# 25      NaN     NaN    NaN
# 26      NaN     NaN    NaN
# 27      NaN     NaN    NaN
# 28      NaN     NaN    NaN
# 29      NaN     NaN    NaN
# ..      ...     ...    ...
# 257     NaN     NaN    NaN
# 258     NaN     NaN    NaN
# 259     NaN     NaN    NaN
# 260     NaN     NaN    NaN
# 261     NaN     NaN    NaN
# 262     NaN     NaN    NaN
# 263     NaN     NaN    NaN
# 264     NaN     NaN    NaN
# 265     NaN     NaN    NaN
# 266     NaN     NaN    NaN
# 267     NaN     NaN    NaN
# 268     NaN     NaN    NaN
# 269     NaN     NaN    NaN
# 270     NaN     NaN    NaN
# 271     NaN     NaN    NaN
# 272     NaN     NaN    NaN
# 273     NaN     NaN    NaN
# 274     NaN     NaN    NaN
# 275     NaN     NaN    NaN
# 276     NaN     NaN    NaN
# 277     NaN     NaN    NaN
# 278     NaN     NaN    NaN
# 279     NaN     NaN    NaN
# 280     NaN     NaN    NaN
# 281     NaN     NaN    NaN
# 282     NaN     NaN    NaN
# 283     NaN     NaN    NaN
# 284     NaN     NaN    NaN
# 285     NaN     NaN    NaN
# 286     NaN     NaN    NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
#
# [287 rows x 407 columns]

# %%
from google.colab import drive
drive.mount('https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-f83e04cff7df> in <module>()
# ----> 1 from google.colab import drive
#       2 drive.mount('https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing')
#
# ModuleNotFoundError: No module named 'google'

# %%
#get the maximum temparature 
df['Temperature'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperature'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d49af94d5c7f> in <module>()
#       1 #get the maximum temparature
# ----> 2 df['Temperature'].max()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperature'

# %%
#to know which day it rains
df['EST'][df['Events'] == 'Rain']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EST'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-85b2f8426390> in <module>()
#       1 #to know which day it rains
# ----> 2 df['EST'][df['Events'] == 'Rain']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EST'

# %%
#3. average wind speed
df['WindSpeedMPH'].mean()
# Out:
# 6.8928571428571432

# %% [markdown]
# # Installation

# %% [markdown]
# pip3 install pandas
